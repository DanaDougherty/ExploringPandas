# %% [markdown]
# # Class 2
# # COMPLETE
# Using Jupyter and Pandas

# %%
# Import pandas module
import pandas as pd

# %% [markdown]
# ## 1. Importing Data
#
# To use pandas, we need data - we can make our own data, or we can import it.
#
# ### 1.1 Making data with a dict
# Here's an example of making data from a dictionary and turning it into a pandas DataFrame

# %%
# Make PFE data using a dictionary.
# The key is a string which will be the column headers in our data frame.
# The value is a list of strings which will give us our rows in the data frame
pfe_data = {'first_name': ['Casey', 'John', 'Suzie', 'Joe'], 'last_name': ['Williams', 'Miller', 'Smith', 'Lee'], 'fall': [250, 275, 190, 205], 'spring': [270, 265, 200, 210]}

# %%
# Make a dataframe object
# Recall that dicts are not stored in any particular order.  By using the columns parameter, we can
#    speficy the order in which to show the dataframe columns
pfe_df = pd.DataFrame(pfe_data, columns = ['first_name', 'last_name', 'fall', 'spring'])

# %%
# Look at the dataframe
pfe_df
# Out:
#   first_name last_name  fall  spring
# 0      Casey  Williams   250     270
# 1       John    Miller   275     265
# 2      Suzie     Smith   190     200
# 3        Joe       Lee   205     210

# %% [markdown]
# ### 1.2 Making data with a list of dicts
# Here's an example of making data from a list of dictionaries and turning it into a pandas DataFrame

# %%
# Make PFE data using a list dictionary.
# Every dictionary will have the same keys, which are the column headers in our data frame.
# The value is a single row's entry in the data frame
pfe_dataALT = [{'first_name': 'Casey', 'last_name': 'Williams', 'fall': 250, 'spring': 270}, 
            {'first_name': 'John', 'last_name': 'Miller', 'fall': 275, 'spring': 265},
            {'first_name': 'Suzie', 'last_name': 'Smith', 'fall': 190, 'spring': 200},
            {'first_name': 'Joe', 'last_name': 'Lee', 'fall': 205, 'spring': 210}]

# %%
# Make a dataframe object
# Recall that dicts are not stored in any particular order.  By using the columns parameter, we can
#    speficy the order in which to show the dataframe columns
pfe_dfALT = pd.DataFrame(pfe_dataALT, columns = ['first_name', 'last_name', 'fall', 'spring'])

# %%
# Look at the dataframe
pfe_dfALT
# Out:
#   first_name last_name  fall  spring
# 0      Casey  Williams   250     270
# 1       John    Miller   275     265
# 2      Suzie     Smith   190     200
# 3        Joe       Lee   205     210

# %% [markdown]
# ### 1.3 Importing data from a csv file
# You'll need to specify the path of where the csv file is, or make sure it's in the same folder that this file is in.

# %%
# We will import a csv file that contains all NYC 311 Service Requests from 2010 to present
# (This data has been subset to only include Agency = NYPD)
df = pd.read_csv('311_from_2011.csv')

# Note that because this is a much larger dataset than what we created, the "preview" of df
#      is only the first 30 rows and the last 30 rows
df
# Out:
#    Unique Key     Created Date      Closed Date Agency  \
# 0    20874484   7/21/2011 2:34   7/21/2011 3:18   NYPD
# 1    20874524   7/21/2011 9:53   7/22/2011 7:56   NYPD
# 2    20874653   7/21/2011 9:04  7/21/2011 13:14   NYPD
# 3    20875098   7/21/2011 9:46  7/21/2011 12:47   NYPD
# 4    20875294  7/21/2011 15:03  7/21/2011 17:59   NYPD
#
#                        Agency Name       Complaint Type  \
# 0  New York City Police Department      Illegal Parking
# 1  New York City Police Department  Homeless Encampment
# 2  New York City Police Department      Illegal Parking
# 3  New York City Police Department      Illegal Parking
# 4  New York City Police Department      Illegal Parking
#
#                        Descriptor    Location Type  Incident Zip  \
# 0                Blocked Sidewalk  Street/Sidewalk       11372.0
# 1                             NaN  Street/Sidewalk       10014.0
# 2   Posted Parking Sign Violation  Street/Sidewalk       10040.0
# 3  Double Parked Blocking Vehicle  Street/Sidewalk       11216.0
# 4  Double Parked Blocking Traffic  Street/Sidewalk       10027.0
#
#     Incident Address                   ...                     \
# 0    35-17 86 STREET                   ...
# 1  643 HUDSON STREET                   ...
# 2  61 ELLWOOD STREET                   ...
# 3     646 PARK PLACE                   ...
# 4                NaN                   ...
#
#   Bridge Highway Name Bridge Highway Direction Road Ramp  \
# 0                 NaN                      NaN       NaN
# 1                 NaN                      NaN       NaN
# 2                 NaN                      NaN       NaN
# 3                 NaN                      NaN       NaN
# 4                 NaN                      NaN       NaN
#
#   Bridge Highway Segment Garage Lot Name Ferry Direction Ferry Terminal Name  \
# 0                    NaN             NaN             NaN                 NaN
# 1                    NaN             NaN             NaN                 NaN
# 2                    NaN             NaN             NaN                 NaN
# 3                    NaN             NaN             NaN                 NaN
# 4                    NaN             NaN             NaN                 NaN
#
#     Latitude  Longitude                                 Location
# 0  40.751852 -73.880894  (40.75185186123101, -73.88089441039439)
# 1  40.739084 -74.005453  (40.73908435163629, -74.00545254558875)
# 2  40.860530 -73.928593  (40.86053025597446, -73.92859340892366)
# 3  40.674064 -73.956206  (40.67406366919581, -73.95620585673406)
# 4  40.809340 -73.959216   (40.8093398080666, -73.95921626658182)
#
# [5 rows x 53 columns]

# %%
# To read about this method (or other methods/functions) and its parameters
#      type ? and then the method name
# ?pd.read_csv

# %% [markdown]
# ## 2. Inspecting the data
#
# You can see this is a large dataset.  Instead we may choose to look at the first few rows or last few rows using the head() and tail() methods

# %% [markdown]
# ### 2.1 Looking at the first / last few rows

# %%
# To look at the first few rows
df.head()
# Out:
#    Unique Key     Created Date      Closed Date Agency  \
# 0    20874484   7/21/2011 2:34   7/21/2011 3:18   NYPD
# 1    20874524   7/21/2011 9:53   7/22/2011 7:56   NYPD
# 2    20874653   7/21/2011 9:04  7/21/2011 13:14   NYPD
# 3    20875098   7/21/2011 9:46  7/21/2011 12:47   NYPD
# 4    20875294  7/21/2011 15:03  7/21/2011 17:59   NYPD
#
#                        Agency Name       Complaint Type  \
# 0  New York City Police Department      Illegal Parking
# 1  New York City Police Department  Homeless Encampment
# 2  New York City Police Department      Illegal Parking
# 3  New York City Police Department      Illegal Parking
# 4  New York City Police Department      Illegal Parking
#
#                        Descriptor    Location Type  Incident Zip  \
# 0                Blocked Sidewalk  Street/Sidewalk       11372.0
# 1                             NaN  Street/Sidewalk       10014.0
# 2   Posted Parking Sign Violation  Street/Sidewalk       10040.0
# 3  Double Parked Blocking Vehicle  Street/Sidewalk       11216.0
# 4  Double Parked Blocking Traffic  Street/Sidewalk       10027.0
#
#     Incident Address                   ...                     \
# 0    35-17 86 STREET                   ...
# 1  643 HUDSON STREET                   ...
# 2  61 ELLWOOD STREET                   ...
# 3     646 PARK PLACE                   ...
# 4                NaN                   ...
#
#   Bridge Highway Name Bridge Highway Direction Road Ramp  \
# 0                 NaN                      NaN       NaN
# 1                 NaN                      NaN       NaN
# 2                 NaN                      NaN       NaN
# 3                 NaN                      NaN       NaN
# 4                 NaN                      NaN       NaN
#
#   Bridge Highway Segment Garage Lot Name Ferry Direction Ferry Terminal Name  \
# 0                    NaN             NaN             NaN                 NaN
# 1                    NaN             NaN             NaN                 NaN
# 2                    NaN             NaN             NaN                 NaN
# 3                    NaN             NaN             NaN                 NaN
# 4                    NaN             NaN             NaN                 NaN
#
#     Latitude  Longitude                                 Location
# 0  40.751852 -73.880894  (40.75185186123101, -73.88089441039439)
# 1  40.739084 -74.005453  (40.73908435163629, -74.00545254558875)
# 2  40.860530 -73.928593  (40.86053025597446, -73.92859340892366)
# 3  40.674064 -73.956206  (40.67406366919581, -73.95620585673406)
# 4  40.809340 -73.959216   (40.8093398080666, -73.95921626658182)
#
# [5 rows x 53 columns]

# %%
# To look at the last few rows
df.tail()
# Out:
#         Unique Key      Created Date       Closed Date Agency  \
# 152615    22335139  12/15/2011 10:31  12/15/2011 14:10   NYPD
# 152616    22335145  12/15/2011 15:55  12/15/2011 18:44   NYPD
# 152617    22335147   12/16/2011 0:48   12/16/2011 1:19   NYPD
# 152618    22335152   12/16/2011 0:16   12/16/2011 6:07   NYPD
# 152619    22335153   12/16/2011 1:45   12/16/2011 3:02   NYPD
#
#                             Agency Name      Complaint Type        Descriptor  \
# 152615  New York City Police Department    Blocked Driveway    Partial Access
# 152616  New York City Police Department     Illegal Parking  Blocked Sidewalk
# 152617  New York City Police Department     Noise - Vehicle     Engine Idling
# 152618  New York City Police Department  Noise - Commercial  Loud Music/Party
# 152619  New York City Police Department  Noise - Commercial  Loud Music/Party
#
#               Location Type  Incident Zip     Incident Address  \
# 152615      Street/Sidewalk       10462.0  1716 WALLACE AVENUE
# 152616      Street/Sidewalk       11220.0        235 55 STREET
# 152617      Street/Sidewalk       11106.0      35-10 35 STREET
# 152618     Store/Commercial       11211.0      149 KENT AVENUE
# 152619  Club/Bar/Restaurant       10014.0        HUDSON STREET
#
#                           ...                    Bridge Highway Name  \
# 152615                    ...                                    NaN
# 152616                    ...                                    NaN
# 152617                    ...                                    NaN
# 152618                    ...                                    NaN
# 152619                    ...                                    NaN
#
#        Bridge Highway Direction Road Ramp Bridge Highway Segment  \
# 152615                      NaN       NaN                    NaN
# 152616                      NaN       NaN                    NaN
# 152617                      NaN       NaN                    NaN
# 152618                      NaN       NaN                    NaN
# 152619                      NaN       NaN                    NaN
#
#        Garage Lot Name Ferry Direction Ferry Terminal Name   Latitude  \
# 152615             NaN             NaN                 NaN  40.844708
# 152616             NaN             NaN                 NaN  40.645788
# 152617             NaN             NaN                 NaN  40.756292
# 152618             NaN             NaN                 NaN  40.719303
# 152619             NaN             NaN                 NaN  40.739716
#
#         Longitude                                  Location
# 152615 -73.863058  (40.844708236171485, -73.86305783580963)
# 152616 -74.018983   (40.64578822699818, -74.01898335282176)
# 152617 -73.925587  (40.756291977616634, -73.92558654393503)
# 152618 -73.962803   (40.719302507197504, -73.9628031024481)
# 152619 -74.005344   (40.73971564962544, -74.00534433919894)
#
# [5 rows x 53 columns]

# %% [markdown]
# ### 2.2 Summary of the data
#
# We can also see a summary of the data by using info() method

# %%
# If we want a summary of df
df.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152620 entries, 0 to 152619
# Data columns (total 53 columns):
# Unique Key                        152620 non-null int64
# Created Date                      152620 non-null object
# Closed Date                       152584 non-null object
# Agency                            152620 non-null object
# Agency Name                       152620 non-null object
# Complaint Type                    152620 non-null object
# Descriptor                        149800 non-null object
# Location Type                     152617 non-null object
# Incident Zip                      152602 non-null float64
# Incident Address                  120132 non-null object
# Street Name                       120132 non-null object
# Cross Street 1                    120337 non-null object
# Cross Street 2                    120316 non-null object
# Intersection Street 1             32035 non-null object
# Intersection Street 2             32035 non-null object
# Address Type                      152394 non-null object
# City                              152616 non-null object
# Landmark                          231 non-null object
# Facility Type                     152616 non-null object
# Status                            152620 non-null object
# Due Date                          152618 non-null object
# Resolution Description            146828 non-null object
# Resolution Action Updated Date    152616 non-null object
# Community Board                   152620 non-null object
# Borough                           152620 non-null object
# X Coordinate (State Plane)        152479 non-null float64
# Y Coordinate (State Plane)        152479 non-null float64
# Park Facility Name                152620 non-null object
# Park Borough                      152620 non-null object
# School Name                       152620 non-null object
# School Number                     152620 non-null object
# School Region                     152620 non-null object
# School Code                       152620 non-null object
# School Phone Number               152620 non-null object
# School Address                    152620 non-null object
# School City                       152620 non-null object
# School State                      152620 non-null object
# School Zip                        152620 non-null object
# School Not Found                  152617 non-null object
# School or Citywide Complaint      0 non-null float64
# Vehicle Type                      0 non-null float64
# Taxi Company Borough              0 non-null float64
# Taxi Pick Up Location             0 non-null float64
# Bridge Highway Name               226 non-null object
# Bridge Highway Direction          226 non-null object
# Road Ramp                         210 non-null object
# Bridge Highway Segment            210 non-null object
# Garage Lot Name                   0 non-null float64
# Ferry Direction                   0 non-null float64
# Ferry Terminal Name               0 non-null float64
# Latitude                          152479 non-null float64
# Longitude                         152479 non-null float64
# Location                          152479 non-null object
# dtypes: float64(12), int64(1), object(40)
# memory usage: 61.7+ MB

# %% [markdown]
# ## 3. Selecting rows / columns
#
# To select row(s) or column(s) we can use the index operator [ ]

# %%
# Selecting rows 7-8
df[7:9]
# Out:
#    Unique Key     Created Date      Closed Date Agency  \
# 7    20875507  7/21/2011 14:06  7/21/2011 14:22   NYPD
# 8    20875542  7/21/2011 15:06  7/22/2011 11:47   NYPD
#
#                        Agency Name    Complaint Type  \
# 7  New York City Police Department   Illegal Parking
# 8  New York City Police Department  Derelict Vehicle
#
#                       Descriptor    Location Type  Incident Zip  \
# 7  Posted Parking Sign Violation  Street/Sidewalk       10016.0
# 8             With License Plate  Street/Sidewalk       11426.0
#
#    Incident Address                   ...                     \
# 7               NaN                   ...
# 8  88-01 242 STREET                   ...
#
#   Bridge Highway Name Bridge Highway Direction Road Ramp  \
# 7                 NaN                      NaN       NaN
# 8                 NaN                      NaN       NaN
#
#   Bridge Highway Segment Garage Lot Name Ferry Direction Ferry Terminal Name  \
# 7                    NaN             NaN             NaN                 NaN
# 8                    NaN             NaN             NaN                 NaN
#
#     Latitude  Longitude                                 Location
# 7  40.745301 -73.986846  (40.745300589915544, -73.9868455439137)
# 8  40.729896 -73.724946  (40.72989590849767, -73.72494554869282)
#
# [2 rows x 53 columns]

# %%
# Select a column by name
df['Complaint Type']
# Out:
# 0                 Illegal Parking
# 1             Homeless Encampment
# 2                 Illegal Parking
# 3                 Illegal Parking
# 4                 Illegal Parking
# 5                 Illegal Parking
# 6                Blocked Driveway
# 7                 Illegal Parking
# 8                Derelict Vehicle
# 9                Blocked Driveway
# 10                Illegal Parking
# 11               Blocked Driveway
# 12               Derelict Vehicle
# 13               Blocked Driveway
# 14               Blocked Driveway
# 15               Blocked Driveway
# 16                Illegal Parking
# 17                Illegal Parking
# 18                Illegal Parking
# 19               Derelict Vehicle
# 20                Illegal Parking
# 21                Noise - Vehicle
# 22                        Vending
# 23               Derelict Vehicle
# 24        Noise - Street/Sidewalk
# 25                   Noise - Park
# 26               Blocked Driveway
# 27               Blocked Driveway
# 28               Blocked Driveway
# 29                Noise - Vehicle
#                    ...
# 152590           Blocked Driveway
# 152591           Blocked Driveway
# 152592         Noise - Commercial
# 152593           Blocked Driveway
# 152594           Derelict Vehicle
# 152595            Illegal Parking
# 152596            Illegal Parking
# 152597            Illegal Parking
# 152598           Blocked Driveway
# 152599           Blocked Driveway
# 152600           Blocked Driveway
# 152601            Illegal Parking
# 152602           Blocked Driveway
# 152603           Derelict Vehicle
# 152604           Blocked Driveway
# 152605           Blocked Driveway
# 152606           Blocked Driveway
# 152607           Blocked Driveway
# 152608        Homeless Encampment
# 152609           Blocked Driveway
# 152610           Derelict Vehicle
# 152611           Derelict Vehicle
# 152612            Illegal Parking
# 152613         Noise - Commercial
# 152614         Noise - Commercial
# 152615           Blocked Driveway
# 152616            Illegal Parking
# 152617            Noise - Vehicle
# 152618         Noise - Commercial
# 152619         Noise - Commercial
# Name: Complaint Type, dtype: object

# %%
# Selecting a column by name, and only showing the first 5 rows
df['Complaint Type'][:5]
# df[:5]['Complaint Type'] results are the same
# Out:
# 0        Illegal Parking
# 1    Homeless Encampment
# 2        Illegal Parking
# 3        Illegal Parking
# 4        Illegal Parking
# Name: Complaint Type, dtype: object

# %%
# Selecting several columns by name gives a new pandas dataframe
df[['Complaint Type', 'Descriptor']][:3]
# Out:
#         Complaint Type                     Descriptor
# 0      Illegal Parking               Blocked Sidewalk
# 1  Homeless Encampment                            NaN
# 2      Illegal Parking  Posted Parking Sign Violation

# %% [markdown]
# ## 4. Column Operations

# %% [markdown]
# ### 4.1 Sorting columns
#
# We may be interested in sorting the dataframe based off a particular column.  We can do this in ascending or descending order.

# %%
df.sort_values(by='Created Date', ascending=True)
# Out:
#       Unique Key   Created Date    Closed Date Agency  \
# 5818    19503332  1/1/2011 0:01  1/1/2011 0:21   NYPD
# 5809    19502937  1/1/2011 0:09  1/1/2011 8:19   NYPD
# 5836    19504859  1/1/2011 0:21  1/1/2011 2:27   NYPD
# 5810    19503050  1/1/2011 0:23  1/1/2011 4:53   NYPD
# 5814    19503087  1/1/2011 0:26  1/1/2011 3:28   NYPD
#
#                           Agency Name      Complaint Type        Descriptor  \
# 5818  New York City Police Department  Noise - Commercial  Loud Music/Party
# 5809  New York City Police Department    Blocked Driveway         No Access
# 5836  New York City Police Department    Blocked Driveway    Partial Access
# 5810  New York City Police Department  Noise - Commercial  Loud Music/Party
# 5814  New York City Police Department    Blocked Driveway    Partial Access
#
#             Location Type  Incident Zip                 Incident Address  \
# 5818     Store/Commercial       10030.0  2498 FREDRICK DOUGLAS BOULEVARD
# 5809      Street/Sidewalk       10457.0                    3813 3 AVENUE
# 5836      Street/Sidewalk       11419.0                104-72 112 STREET
# 5810  Club/Bar/Restaurant       10003.0                 81 EAST 7 STREET
# 5814      Street/Sidewalk       11379.0                  63-38 78 STREET
#
#                         ...                    Bridge Highway Name  \
# 5818                    ...                                    NaN
# 5809                    ...                                    NaN
# 5836                    ...                                    NaN
# 5810                    ...                                    NaN
# 5814                    ...                                    NaN
#
#      Bridge Highway Direction Road Ramp Bridge Highway Segment  \
# 5818                      NaN       NaN                    NaN
# 5809                      NaN       NaN                    NaN
# 5836                      NaN       NaN                    NaN
# 5810                      NaN       NaN                    NaN
# 5814                      NaN       NaN                    NaN
#
#      Garage Lot Name Ferry Direction Ferry Terminal Name   Latitude  \
# 5818             NaN             NaN                 NaN  40.815538
# 5809             NaN             NaN                 NaN  40.837570
# 5836             NaN             NaN                 NaN  40.684662
# 5810             NaN             NaN                 NaN  40.727265
# 5814             NaN             NaN                 NaN  40.719303
#
#       Longitude                                  Location
# 5818 -73.947236   (40.81553801930246, -73.94723632272968)
# 5809 -73.901673   (40.83757019909911, -73.90167273075315)
# 5836 -73.830089  (40.684662155286006, -73.83008853932155)
# 5810 -73.986409  (40.727264767093544, -73.98640893693863)
# 5814 -73.876880  (40.719303068736096, -73.87687971030206)
#
# [5 rows x 53 columns]

# %% [markdown]
# ### 4.2 Creating a new column
#
# We also may want to add a column to our dataframe.  Possibly from a combination of our other columns or maybe all "hard coded" with some number or string.

# %%
df['Complaint'] = df['Complaint Type'] + df['Descriptor']
df[:1]
# Out:
#    Unique Key    Created Date     Closed Date Agency  \
# 0    20874484  7/21/2011 2:34  7/21/2011 3:18   NYPD
#
#                        Agency Name   Complaint Type        Descriptor  \
# 0  New York City Police Department  Illegal Parking  Blocked Sidewalk
#
#      Location Type  Incident Zip Incident Address  \
# 0  Street/Sidewalk       11372.0  35-17 86 STREET
#
#                 ...                Bridge Highway Direction Road Ramp  \
# 0               ...                                     NaN       NaN
#
#   Bridge Highway Segment Garage Lot Name Ferry Direction Ferry Terminal Name  \
# 0                    NaN             NaN             NaN                 NaN
#
#     Latitude  Longitude                                 Location  \
# 0  40.751852 -73.880894  (40.75185186123101, -73.88089441039439)
#
#                          Complaint
# 0  Illegal ParkingBlocked Sidewalk
#
# [1 rows x 54 columns]

# %% [markdown]
# ### 4.3 Unique values in a column
#
# To get an array of all unique values in a particular column, use the .unique() method

# %%
df['Incident Zip'].unique()
# Out:
# array([ 11372.,  10014.,  10040.,  11216.,  10027.,  10034.,  11355.,
#         10016.,  11426.,  11212.,  11236.,  11220.,  11434.,  10465.,
#         11423.,  10467.,  10036.,  11378.,  11229.,  10452.,  10312.,
#         11230.,  10013.,  10466.,  10472.,  11207.,  11421.,  11435.,
#         10017.,  11368.,  11103.,  10025.,  10307.,  11416.,  11375.,
#         11223.,  10021.,  11218.,  10023.,  10460.,  11208.,  11418.,
#         11206.,  11377.,  10305.,  10462.,  11224.,  11357.,  11214.,
#         10031.,  11234.,  10309.,  11356.,  10458.,  11211.,  11413.,
#         11210.,  11004.,  11361.,  10029.,  11427.,  10455.,  10010.,
#         11419.,  11105.,  10002.,  10461.,  10009.,  11374.,  10456.,
#         11231.,  10314.,  11417.,  11225.,  11102.,  11433.,  10012.,
#         10018.,  11379.,  11213.,  10007.,  11217.,  10280.,  10306.,
#         10019.,  11693.,  11385.,  11432.,  10468.,  11235.,  11222.,
#         11221.,  10003.,  10032.,  11219.,  11691.,  10024.,  10004.,
#         10308.,  10038.,  11354.,  11203.,  11101.,  11226.,  11365.,
#         11106.,  11420.,  11436.,  10469.,  11428.,  11232.,  11238.,
#         10464.,  10457.,  11204.,  11373.,  11215.,  11367.,  11370.,
#         11237.,  11369.,  10473.,  11422.,  10033.,  11694.,  11415.,
#         11429.,  10451.,  10039.,  10301.,  10304.,  10065.,  11209.,
#         11364.,  11233.,  10006.,  10128.,  10474.,  10454.,  11412.,
#         11363.,  11104.,  10035.,  10459.,  11411.,  10302.,  10303.,
#         11692.,  11366.,  11414.,  10011.,  10026.,  10001.,  11205.,
#         11358.,  10310.,  10075.,  10022.,  11228.,  10463.,  10030.,
#         10453.,  10028.,  10000.,  11109.,  10037.,  11201.,  10470.,
#         11239.,  11360.,  10475.,  10471.,  11362.,  10005.,  11040.,
#         10020.,  11001.,  10069.,  10282.,  11243.,  11430.,     nan,
#         10281.,  10048.,  11697.,  10400.,  10044.,  11371.])

# %% [markdown]
# ### 4.4 Column Statistics
#
# You can isolate a column and find the max, min, sum of a column.  For example, we may be interested in finding the zipcode shows up the most in this dataset...i.e. we are looking for the mode.

# %%
from statistics import mode

mode(df['Incident Zip'])
# Out:
# 11211.0

# %% [markdown]
# ## 5.  Counting values
#
# ### 5.1 Counting values in a given column
#
# If we are curious how many times each value appears in the dataset, we can use the value_counts() method

# %%
# This gets the top 10 complaint types
df['Complaint Type'].value_counts()[:10]
# Out:
# Blocked Driveway           48260
# Illegal Parking            31867
# Noise - Commercial         16804
# Noise - Street/Sidewalk    16562
# Derelict Vehicle           12081
# Noise - Vehicle            11658
# Vending                     3897
# Traffic                     2870
# Noise - Park                2182
# Homeless Encampment         1734
# Name: Complaint Type, dtype: int64

# %% [markdown]
# ### 5.2 Making a bar graph

# %%
# %matplotlib inline
df['Complaint Type'].value_counts()[:10].plot(kind='bar')

# %% [markdown]
# ## 6. Isolating columns with a certain value

# %%
# Find all columns whose complaints are noise-residential
noise_res = df[ df['Complaint Type'] == 'Noise - Residential']
noise_res.head()
# Out:
#       Unique Key     Created Date     Closed Date Agency  \
# 5770    19832686   2/14/2011 5:28  2/14/2011 5:59   NYPD
# 5771    20884743   7/23/2011 0:44  7/23/2011 2:50   NYPD
# 5772    20893111   7/24/2011 1:33  7/24/2011 2:57   NYPD
# 5773    20893310  7/23/2011 22:56  7/24/2011 0:03   NYPD
# 5774    20897283   7/24/2011 3:18  7/24/2011 4:02   NYPD
#
#                           Agency Name       Complaint Type        Descriptor  \
# 5770  New York City Police Department  Noise - Residential  Loud Music/Party
# 5771  New York City Police Department  Noise - Residential  Loud Music/Party
# 5772  New York City Police Department  Noise - Residential  Loud Music/Party
# 5773  New York City Police Department  Noise - Residential  Loud Music/Party
# 5774  New York City Police Department  Noise - Residential  Loud Music/Party
#
#                    Location Type  Incident Zip     Incident Address  \
# 5770  Residential Building/House       10027.0  445 WEST 125 STREET
# 5771  Residential Building/House       11221.0                  NaN
# 5772  Residential Building/House       11210.0                  NaN
# 5773  Residential Building/House       11432.0                  NaN
# 5774  Residential Building/House       11368.0            51 AVENUE
#
#                      ...                  Bridge Highway Direction Road Ramp  \
# 5770                 ...                                       NaN       NaN
# 5771                 ...                                       NaN       NaN
# 5772                 ...                                       NaN       NaN
# 5773                 ...                                       NaN       NaN
# 5774                 ...                                       NaN       NaN
#
#      Bridge Highway Segment Garage Lot Name Ferry Direction  \
# 5770                    NaN             NaN             NaN
# 5771                    NaN             NaN             NaN
# 5772                    NaN             NaN             NaN
# 5773                    NaN             NaN             NaN
# 5774                    NaN             NaN             NaN
#
#      Ferry Terminal Name   Latitude  Longitude  \
# 5770                 NaN  40.812391 -73.955400
# 5771                 NaN  40.684300 -73.941203
# 5772                 NaN  40.627289 -73.942161
# 5773                 NaN  40.707220 -73.789569
# 5774                 NaN  40.744377 -73.853798
#
#                                       Location  \
# 5770   (40.81239052615086, -73.95539955212213)
# 5771  (40.684300477367344, -73.94120342857268)
# 5772    (40.6272891050122, -73.94216148982389)
# 5773  (40.707220377108214, -73.78956938390046)
# 5774      (40.74437688806, -73.85379802970152)
#
#                                 Complaint
# 5770  Noise - ResidentialLoud Music/Party
# 5771  Noise - ResidentialLoud Music/Party
# 5772  Noise - ResidentialLoud Music/Party
# 5773  Noise - ResidentialLoud Music/Party
# 5774  Noise - ResidentialLoud Music/Party
#
# [5 rows x 54 columns]

# %%
# We can subset based on more than one column
# For example, if we want a data frame with all the noise-residential complaints in zip 10027
noise_res = df[ (df['Complaint Type'] == 'Noise - Residential') & (df['Incident Zip'] == 11221) ]
noise_res.head()
# Out:
#       Unique Key     Created Date     Closed Date Agency  \
# 5771    20884743   7/23/2011 0:44  7/23/2011 2:50   NYPD
# 5781    20944035  7/31/2011 23:03   8/1/2011 2:52   NYPD
#
#                           Agency Name       Complaint Type        Descriptor  \
# 5771  New York City Police Department  Noise - Residential  Loud Music/Party
# 5781  New York City Police Department  Noise - Residential  Loud Music/Party
#
#                    Location Type  Incident Zip Incident Address  \
# 5771  Residential Building/House       11221.0              NaN
# 5781  Residential Building/House       11221.0              NaN
#
#                      ...                  Bridge Highway Direction Road Ramp  \
# 5771                 ...                                       NaN       NaN
# 5781                 ...                                       NaN       NaN
#
#      Bridge Highway Segment Garage Lot Name Ferry Direction  \
# 5771                    NaN             NaN             NaN
# 5781                    NaN             NaN             NaN
#
#      Ferry Terminal Name   Latitude  Longitude  \
# 5771                 NaN  40.684300 -73.941203
# 5781                 NaN  40.689631 -73.927403
#
#                                       Location  \
# 5771  (40.684300477367344, -73.94120342857268)
# 5781  (40.689631179170966, -73.92740258439997)
#
#                                 Complaint
# 5771  Noise - ResidentialLoud Music/Party
# 5781  Noise - ResidentialLoud Music/Party
#
# [2 rows x 54 columns]

# %% [markdown]
# ## 7. Bar Chart

# %%
# To see which Borough has the most 311 calls

import matplotlib
# %matplotlib inline

df['Borough'].value_counts().plot(kind='bar')

# %%
(df['Borough'].value_counts()/sum(df['Borough'].value_counts())).plot(kind='bar')
